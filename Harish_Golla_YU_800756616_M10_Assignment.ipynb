# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as ChromeService
import pandas as pd
import time
from selenium.webdriver.chrome.service import Service
import numpy as np
import boto3

# Initialize the WebDriver
driver = webdriver.Chrome()



# Navigate to the website
driver.get('https://www.charitiesnys.com/RegistrySearch/search_charities.jsp')

# Find and fill the input element
inputElement = driver.find_element(By.XPATH, '//input[@name="orgName"]')
inputElement.send_keys('0')

# Find and click the submit button
submitButton = driver.find_element(By.XPATH, '//input[@class="submitButton"]')


submitButton.click()

# Wait for the table to load
time.sleep(4)


table = driver.find_element(By.XPATH, '/html/body/div[2]/div/table/tbody/tr/td[3]/div/div/table[2]')

df =[]

#loop through dataframe to export table
for row in table.find_elements(By.TAG_NAME, 'tr'):
      cols = df.append([cell.text for cell in row.find_elements(By.TAG_NAME, 'td')])

df = pd.DataFrame(df, columns = ["Organization Name", "NY Reg #", "EIN" ,"Registrant Type","City","State"])
# df.dropna()
df = df.replace(to_replace='None', value=np.nan).dropna()
display(df)
# print(df)

# Close the WebDriver
driver.quit()


# AWS credentials and region
aws_access_key_id = 'AKIA6CFWX4GLYQQUCDM4'
aws_secret_access_key = 'fXlY5Is4g/AAuiiHKKPQ3ujEW9F/VYSqZmjJ2pXm'
region_name = 'us-east-1'
bucket_name = 'harishgollabucket'

# Create an S3 client
s3 = boto3.client('s3', aws_access_key_id=aws_access_key_id, aws_secret_access_key=aws_secret_access_key, region_name=region_name)

# File path and name
pathname = 's3://m10/'
filename = 'charities_bureau_scrape_'
datetime = time.strftime('%Y%m%d%H%M%S')
filenames3 = f'{pathname}{filename}{datetime}.csv'

# Save DataFrame to a CSV file
df.to_csv('scrape.csv', header=True, index=False, line_terminator='\n')

# Upload the file to S3
with open('scrape.csv', 'rb') as file:
    s3.upload_fileobj(file, bucket_name, filenames3)
# Out:
#                                     Organization Name  NY Reg #  \
# 1                                  "Studio 5404" Inc.  44-39-58
# 2                                              038249  15-68-83
# 3                                 04/11 10:17 PM test  47-13-95
# 4                                 1/20/21 Action Fund  46-99-13
# 5                          10,000 Entrepreneurs, Inc.  47-42-99
# 6                             10/40 Connections, Inc.  45-70-15
# 7                              1000 Feet Project, Inc  45-00-14
# 8                           1000 Islands Hose Haulers  45-38-38
# 9   1000 Islands Regional Local Development Corpor...  47-98-37
# 10                           1000 Steps Fellows, Inc.  47-01-23
# 11                              1004 Foundation, Inc.  45-00-13
# 12  100 BLACK MEN OF LONG ISLAND DEVELOPMENT GROUP...  20-08-47
# 13                      100 Black Men of Syracuse Inc  48-39-60
# 14                            100 BLACKS WHO CARE INC  06-42-84
# ...

# %%
import boto3

# AWS credentials and region
aws_access_key_id = 'AKIA6CFWX4GLYQQUCDM4'
aws_secret_access_key = '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'
region_name = 'us-east-1'

# Create an S3 client
s3 = boto3.client('s3', aws_access_key_id=aws_access_key_id, aws_secret_access_key=aws_secret_access_key, region_name=region_name)

# File path and name
filename = 'scrape.csv'
s3_filename = 's3_scrape.csv'
bucket_name = 'harishgollabucket'

# Upload the file to S3
try:
    s3.upload_file(filename, bucket_name, s3_filename)
    print("File uploaded successfully!")
except Exception as e:
    print("An error occurred while uploading the file:", str(e))
# Out:
# File uploaded successfully!

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import boto3
import time

def pulldata():
    df =[]
    table = driver.find_element(By.XPATH, '/html/body/div[2]/div/table/tbody/tr/td[3]/div/div/table[2]')

    #loop through dataframe to export table
    for row in table.find_elements(By.TAG_NAME, 'tr'):
          cols = df.append([cell.text for cell in row.find_elements(By.TAG_NAME, 'td')])

    df = pd.DataFrame(df, columns = ["Organization Name", "NY Reg #", "EIN" ,"Registrant Type","City","State"])
    
    return df


# AWS credentials and region
aws_access_key_id = 'AKIA6CFWX4GLYQQUCDM4'
aws_secret_access_key = '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'
region_name = 'us-east-1'
bucket_name = 'harishgollabucket'


driver = webdriver.Chrome()

driver.get('https://www.charitiesnys.com/RegistrySearch/search_charities.jsp')

# Find and fill the input element
inputElement = driver.find_element(By.XPATH, '//input[@name="orgName"]')
# inputElement = driver.find_element(By.XPATH, '')
inputElement.send_keys('0')

# Find and click the submit button
submitButton = driver.find_element(By.XPATH, '//input[@class="submitButton"]')


submitButton.click()

# Wait for the table to load
time.sleep(4)

#get the data from the function
pulldata()

# Find the pagination links
pagination_links = driver.find_elements(By.XPATH, "//a[starts-with(@title, 'Go to page')]")
df1 = []
i = 0

page_links = [link.get_attribute('href') for link in pagination_links]


for page_url in page_links:
    driver.get(page_url)
    time.sleep(4)
    df1 = pulldata()
    df = df.append(df1,ignore_index=True)
    df1 = []
    i += 1

df = df.replace(to_replace='None', value=np.nan).dropna()
df = df.drop_duplicates()
driver.quit()




# Create an S3 client
s3 = boto3.client('s3', aws_access_key_id=aws_access_key_id, aws_secret_access_key=aws_secret_access_key, region_name=region_name)

# File path and name
pathname = 's3://m10/'
filename = 'charities_bureau_scrape_alldata'
datetime = time.strftime('%Y%m%d%H%M%S')
filenames3 = f'{pathname}{filename}{datetime}.csv'

# Save DataFrame to a CSV file
df.to_csv('scrape.csv', header=True, index=False, line_terminator='\n')

# Upload the file to S3
with open('scrape.csv', 'rb') as file:
    s3.upload_fileobj(file, bucket_name, filenames3)
# Out:
# C:\Users\12015\AppData\Local\Temp\ipykernel_39360\3941029007.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df1,ignore_index=True)
# C:\Users\12015\AppData\Local\Temp\ipykernel_39360\3941029007.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df1,ignore_index=True)
# C:\Users\12015\AppData\Local\Temp\ipykernel_39360\3941029007.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df1,ignore_index=True)
# C:\Users\12015\AppData\Local\Temp\ipykernel_39360\3941029007.py:60: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df1,ignore_index=True)
# ...
